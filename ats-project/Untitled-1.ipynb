# %%
# %pip install pandas
import pandas as pd
import numpy as np
import re
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/utpal.gohain/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/utpal.gohain/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('parsed_resumes.csv')
df.head(5)
# Out:
#   candidate_id       resume_file_name candidate_name primary_domain  \
# 0   CND_100001      DataAnalyst_1.pdf    Candidate_1   Data Science
# 1   CND_100002          profile_2.pdf    Candidate_2             IT
# 2   CND_100003  Legal_candidate_3.pdf    Candidate_3          Legal
# 3   CND_100004     IT_candidate_4.pdf    Candidate_4             IT
# 4   CND_100005     IT_candidate_5.pdf    Candidate_5             IT
#
#                primary_role  years_experience highest_education  \
# 0              Data Analyst                 7               LLM
# 1  Senior Software Engineer                10           Masters
# 2        Compliance Officer                 7               LLM
# 3  Senior Software Engineer                 9               LLM
# 4         Software Engineer                 9           Masters
#
#           education_field institution_tier  \
# 0             Mathematics           Tier-1
# 1        Computer Science           Tier-2
# 2                     Law           Tier-1
# 3        Computer Science           Tier-1
# 4  Information Technology           Tier-1
#
#                                 technical_skills_raw  ...  \
# 0         Machine Learning, Power BI, Pandas, Python  ...
# 1                    Kubernetes, Git, Docker, Python  ...
# 2  Due Diligence, Legal Research, Compliance, Con...  ...
# 3                       Kubernetes, AWS, SQL, Docker  ...
# 4                         Java, Kubernetes, Git, AWS  ...
#
#   enterprise_systems_experience_flag offshore_onsite_model_experience_flag  \
# 0                                  1                                     1
# 1                                  1                                     1
# 2                                  1                                     1
# 3                                  1                                     1
# 4                                  1                                     1
#
#   multi_vendor_coordination_flag process_compliance_experience_flag  \
# 0                              1                                  1
# 1                              1                                  1
# 2                              1                                  1
# 3                              1                                  1
# 4                              1                                  1
#
#   documentation_heavy_role_flag  mentoring_experience_flag  \
# 0                             0                          1
# 1                             1                          1
# 2                             1                          1
# 3                             1                          1
# 4                             1                          1
#
#    stakeholder_management_experience_flag  resume_length_words  \
# 0                                       1                   56
# 1                                       1                   54
# 2                                       1                   57
# 3                                       1                   55
# 4                                       1                   51
#
#    keyword_density_score  profile_completeness_score
# 0                   0.74                        0.61
# 1                   0.89                        0.89
# 2                   0.40                        0.56
# 3                   0.74                        0.89
# 4                   0.58                        0.59
#
# [5 rows x 34 columns]

# %%
#MAke a copy of the dataframe
df_clean = df.copy()

# %%
#Handle Missing Values
df_clean.isnull().sum()
# Out:
# candidate_id                                0
# resume_file_name                            0
# candidate_name                              0
# primary_domain                              0
# primary_role                                0
# years_experience                            0
# highest_education                         270
# education_field                           237
# institution_tier                            0
# technical_skills_raw                        0
# tools_platforms_raw                         0
# soft_skills_raw                             0
# experience_summary                          0
# project_summary                             0
# key_achievements                            0
# management_experience_flag                  0
# people_management_flag                      0
# project_management_experience_flag          0
# agile_scrum_experience_flag                 0
# client_facing_experience_flag               0
# delivery_lead_experience_flag               0
# cloud_experience_flag                       0
# ml_experience_flag                          0
# compliance_experience_flag                  0
# enterprise_systems_experience_flag          0
# offshore_onsite_model_experience_flag       0
# multi_vendor_coordination_flag              0
# process_compliance_experience_flag          0
# documentation_heavy_role_flag               0
# mentoring_experience_flag                   0
# stakeholder_management_experience_flag      0
# resume_length_words                         0
# keyword_density_score                       0
# profile_completeness_score                  0
# dtype: int64

# %%
# Missing text = no info → replace with ""

text_cols = [
    'technical_skills_raw',
    'tools_platforms_raw',
    'soft_skills_raw',
    'experience_summary',
    'project_summary',
    'key_achievements'
]
text_columns = df_clean[text_cols]
# Fill missing values with empty strings
for col in text_cols:
    df_clean[col] = df_clean[col].fillna('')
